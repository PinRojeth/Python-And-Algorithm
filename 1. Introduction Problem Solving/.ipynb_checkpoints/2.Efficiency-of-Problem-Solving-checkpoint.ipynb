# %% [markdown]
# ![Screenshot%202023-10-02%20at%209.38.09%20AM.png](attachment:Screenshot%202023-10-02%20at%209.38.09%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20at%209.41.00%20AM.png](attachment:Screenshot%202023-10-02%20at%209.41.00%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20at%209.44.11%20AM.png](attachment:Screenshot%202023-10-02%20at%209.44.11%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20at%209.48.29%20AM.png](attachment:Screenshot%202023-10-02%20at%209.48.29%20AM.png)

# %%
for i in range(n + 1) : 
    s1 = 0
    s1 += i
