# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.26.01%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.26.01%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.27.25%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.27.25%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.27.34%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.27.34%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.28.31%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.28.31%20AM.png)

# %% [markdown]
# Bitonic Sequence is the list that contain element from increase to decrease. Ex : [1, 3, 5 ,7, 6, 4, 2]

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.32.36%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.32.36%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.32.45%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.32.45%20AM.png)

# %%
# Solution 1 using recusion

def binSearch(low, high, n, s) : 
    mid = (low + high) // 2
    if mid == 0 or mid > n - 1 : 
        return -1
    else : 
        if s[mid-1] < s[mid] > s[mid + 1]: 
            return mid 
        elif s[mid - 1] < s[mid] < s[mid + 1] : 
            return binSearch(mid + 1, high, n, s)
        else :
            return binSearch(low, mid - 1, n, s)
        
def solve(n, s) : 
    j = binSearch(0, n - 1, n, s) 
    print(j, s[j])
n = int(input())
s = list(map(int, input().split()))
solve(n, s)
# Out:
# 7
# 18 27 42 82 73 67 25
# 3 82

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.40.40%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.40.40%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.44.48%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.44.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.44.58%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.44.58%20AM.png)

# %%
def binSearch(n, s) : 
    low, high = 0, n - 1
    mid = (low + high) // 2
    while mid != 0 and mid != n - 1 : 
        mid = (low + high) // 2
        if s[mid - 1] < s[mid] > s[mid + 1]: 
            return mid
        elif s[mid - 1] < s[mid] > s[mid + 1] : 
            low = mid + 1
        else : 
            high = mid - 1
            
    return -1

def solve(n, s) : 
    j = binSearch(n, s)
    print(j, s[j])

n = int(input())
s = list(map(int, input().split()))
solve(n, s)
# Out:
# 10
# 17 95 87 56 49 42 37 31 21 20
# 1 95

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.46.13%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.46.13%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2011.46.40%20AM.png](attachment:Screenshot%202023-11-20%20at%2011.46.40%20AM.png)
