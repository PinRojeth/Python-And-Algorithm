# %% [markdown]
# ![Screenshot%202023-11-20%20at%209.23.15%20AM.png](attachment:Screenshot%202023-11-20%20at%209.23.15%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%209.25.07%20AM.png](attachment:Screenshot%202023-11-20%20at%209.25.07%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%209.26.12%20AM.png](attachment:Screenshot%202023-11-20%20at%209.26.12%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%209.37.47%20AM.png](attachment:Screenshot%202023-11-20%20at%209.37.47%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%209.39.34%20AM.png](attachment:Screenshot%202023-11-20%20at%209.39.34%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%209.39.46%20AM.png](attachment:Screenshot%202023-11-20%20at%209.39.46%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%209.40.52%20AM.png](attachment:Screenshot%202023-11-20%20at%209.40.52%20AM.png)

# %%
# Solution 1 using Iteration

def binSearch(x, n, s) : 
    low = 0 
    high = n - 1 
    cnt = 0 
    while low <= high : 
        mid = (low + high) // 2 
        cnt += 1 
        if x == s[mid] : 
            return cnt
        elif x < s[mid] : 
            high = mid -1 
        else : 
            low = mid + 1 
    return cnt

def solve(n, m, s, x) : 
    total = 0
    for i in range(m) :

        total += binSearch(x[i], n, s)
    print(total)
    
n,m = map(int, input().split())
s = list(map(int, input().split()))
x = list(map(int, input().split()))
solve(n, m, s, x)
# Out:
# 10 10
# 17 46 49 62 66 76 78 79 84 98
# 78 46 66 79 49 84 17 76 98 62
# 29

# %% [markdown]
# ![Screenshot%202023-11-20%20at%209.52.00%20AM.png](attachment:Screenshot%202023-11-20%20at%209.52.00%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2010.05.09%20AM.png](attachment:Screenshot%202023-11-20%20at%2010.05.09%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2010.08.53%20AM.png](attachment:Screenshot%202023-11-20%20at%2010.08.53%20AM.png)

# %%
def binSearch(low, high, x, s) : 
    if low > high : 
        return 0 
    else :
        mid = (low + high) // 2 
        if x == s[mid] : 
            return 1 
        elif x < s[mid]: 
            return 1 + binSearch(low, mid - 1, x, s)
        else :
            return 1 + binSearch(mid + 1, high, x, s) 
    
def solve(n, m, s, x) :
    total = 0
    for i in range(m) : 
        total += binSearch(0, n - 1, x[i], s)
    print(total)
    
n,m = map(int, input().split())
s = list(map(int, input().split()))
x = list(map(int, input().split()))
solve(n, m, s, x)
# Out:
# 10 10
# 17 46 49 62 66 76 78 79 84 98
# 78 46 66 79 49 84 17 76 98 62
# 29

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2010.09.26%20AM.png](attachment:Screenshot%202023-11-20%20at%2010.09.26%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-20%20at%2010.10.08%20AM.png](attachment:Screenshot%202023-11-20%20at%2010.10.08%20AM.png)
