# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.32.23%20AM.png](attachment:Screenshot%202023-11-21%20at%208.32.23%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.33.44%20AM.png](attachment:Screenshot%202023-11-21%20at%208.33.44%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.34.06%20AM.png](attachment:Screenshot%202023-11-21%20at%208.34.06%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.35.52%20AM.png](attachment:Screenshot%202023-11-21%20at%208.35.52%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.39.43%20AM.png](attachment:Screenshot%202023-11-21%20at%208.39.43%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.39.58%20AM.png](attachment:Screenshot%202023-11-21%20at%208.39.58%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.40.52%20AM.png](attachment:Screenshot%202023-11-21%20at%208.40.52%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.50.25%20AM.png](attachment:Screenshot%202023-11-21%20at%208.50.25%20AM.png)

# %%
def binsearch(low, high, n, s) : 
    if low == high: 
        if s[low] % 2 != 0 : 
            return -1
        else :
            return low
    else : 
        mid = (low + high) // 2 
        if s[mid] % 2 == 0 : 
            return binsearch(low, mid, n, s)
        else : 
            return binsearch(mid + 1, high, n, s)
        
def solve(n, s) : 
    j = binsearch(0, n - 1, n, s)
    print(0 if j < 0 else s[j])
    
n = int(input())
s = list(map(int, input().split()))
solve(n, s)
# Out:
# 8
# 7 3 1 9 8 4 2 6
# 8

# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.53.25%20AM.png](attachment:Screenshot%202023-11-21%20at%208.53.25%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%208.57.24%20AM.png](attachment:Screenshot%202023-11-21%20at%208.57.24%20AM.png)

# %%
def binsearch(n, s) : 
    low, high = 0, n - 1 
    while low < high : 
        mid = (low + high) // 2
        if s[mid] % 2 == 0 : 
            high = mid 
        else :
            low = mid + 1 
    return -1 if s[low] % 2 == 1 else low 
def solve(n, s) : 
    j = binsearch(n, s)
    print(0 if j < 0 else s[j])
    
n = int(input())
s = list(map(int, input().split()))
solve(n, s)
# Out:
# 8
# 7 3 1 9 8 4 2 6
# 8

# %% [markdown]
# ![Screenshot%202023-11-21%20at%209.00.57%20AM.png](attachment:Screenshot%202023-11-21%20at%209.00.57%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%209.01.25%20AM.png](attachment:Screenshot%202023-11-21%20at%209.01.25%20AM.png)
