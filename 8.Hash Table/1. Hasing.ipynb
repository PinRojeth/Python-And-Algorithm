# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.15.06%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.15.06%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.15.31%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.15.31%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.23.51%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.23.51%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.24.16%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.24.16%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.29.31%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.29.31%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.41.51%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.41.51%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.51.13%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.51.13%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.51.32%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.51.32%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.54.45%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.54.45%20AM.png)

# %%
def hash(s) : 
    key = 0 
    for i in range(len(s)) :
        key += (ord(s[i]) - ord('a') + 1) * (r ** i)
    return key % m
r, m = map(int, input().split())
s = input()
hashkey = hash(s)
print(hashkey)
# Out:
# 31 1234
# abc
# 478

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2011.57.11%20AM.png](attachment:Screenshot%202023-12-11%20at%2011.57.11%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-11%20at%2012.01.33%20PM.png](attachment:Screenshot%202023-12-11%20at%2012.01.33%20PM.png)
