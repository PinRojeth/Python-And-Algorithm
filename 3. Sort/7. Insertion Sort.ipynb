# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.57.48%20AM.png](attachment:Screenshot%202023-11-02%20at%209.57.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.58.21%20AM.png](attachment:Screenshot%202023-11-02%20at%209.58.21%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.00.33%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.00.33%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.00.59%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.00.59%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.01.19%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.01.19%20AM.png)

# %%
def insertionsort(n, s) :
    cnt = 0 
    for i in range(1, n) :
        j, val = i - 1, s[i]
        cnt+= 1 
        while j >= 0 and s[j] > val :
            s[j + 1] = s[j]
            j -= 1 
            cnt += 1 
        s[j + 1] = val 
    return cnt 

n = int(input())
s = list(map(int, input().split()))
print(insertionsort(n, s))
# Out:
# 7
# 70 60 50 40 30 20 10
# 27

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.26.18%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.26.18%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.26.58%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.26.58%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.27.46%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.27.46%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.27.58%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.27.58%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.28.32%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.28.32%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.28.56%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.28.56%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%2010.29.17%20AM.png](attachment:Screenshot%202023-11-02%20at%2010.29.17%20AM.png)
