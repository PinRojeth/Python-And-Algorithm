# %% [markdown]
# ![Screenshot%202023-12-06%20at%2010.14.21%20AM.png](attachment:Screenshot%202023-12-06%20at%2010.14.21%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-06%20at%2010.15.34%20AM.png](attachment:Screenshot%202023-12-06%20at%2010.15.34%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-06%20at%2010.15.51%20AM.png](attachment:Screenshot%202023-12-06%20at%2010.15.51%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-06%20at%2010.19.43%20AM.png](attachment:Screenshot%202023-12-06%20at%2010.19.43%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-06%20at%2010.22.12%20AM.png](attachment:Screenshot%202023-12-06%20at%2010.22.12%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-06%20at%2010.27.06%20AM.png](attachment:Screenshot%202023-12-06%20at%2010.27.06%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-06%20at%2010.43.48%20AM.png](attachment:Screenshot%202023-12-06%20at%2010.43.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-06%20at%2010.44.35%20AM.png](attachment:Screenshot%202023-12-06%20at%2010.44.35%20AM.png)

# %%
def solve(cmd, queue) : 
    if cmd[0] == "push_front" : 
        queue.append(cmd[1])
    elif cmd[0] == "push_back" : 
        queue.appendleft(cmd[1])
    elif cmd[0] == "pop_front" : 
        print("Oops!" if not queue else queue.pop())
    elif cmd[0] == "pop_back" : 
        print("Oops!" if not queue else queue.popleft())
    elif cmd[0] == "peek_front" : 
        print("None!" if not queue else queue[-1])
    elif cmd[0] == "peek_back" : 
        print("None!" if not queue else queue[0])
        
from collections import deque 
n = int(input())
queue = deque()
for _ in range(n) : 
    cmd = input().split()
    solve(cmd, queue)
# Out:
# 15
# push_back A
# push_front B
# push_front C
# pop_front
# C
# pop_back
# A
# push_front D
# push_back E
# peek_front
# D
# peek_back
# E
# pop_front
# D
# pop_back
# E
# pop_front
# B
# pop_back
# Oops!
# peek_front
# None!
# peek_back
# None!

# %% [markdown]
# ![Screenshot%202023-12-06%20at%2011.13.11%20AM.png](attachment:Screenshot%202023-12-06%20at%2011.13.11%20AM.png)
