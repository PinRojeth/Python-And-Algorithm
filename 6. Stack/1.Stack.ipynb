# %% [markdown]
# ![Screenshot%202023-11-21%20at%2011.31.12%20AM.png](attachment:Screenshot%202023-11-21%20at%2011.31.12%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%2011.31.48%20AM.png](attachment:Screenshot%202023-11-21%20at%2011.31.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%2011.37.51%20AM.png](attachment:Screenshot%202023-11-21%20at%2011.37.51%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20at%2011.39.51%20AM.png](attachment:Screenshot%202023-11-21%20at%2011.39.51%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.05.21%20AM.png](attachment:Screenshot%202023-11-22%20at%209.05.21%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.07.20%20AM.png](attachment:Screenshot%202023-11-22%20at%209.07.20%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.10.50%20AM.png](attachment:Screenshot%202023-11-22%20at%209.10.50%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.10.57%20AM.png](attachment:Screenshot%202023-11-22%20at%209.10.57%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.11.09%20AM.png](attachment:Screenshot%202023-11-22%20at%209.11.09%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.13.08%20AM.png](attachment:Screenshot%202023-11-22%20at%209.13.08%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.13.32%20AM.png](attachment:Screenshot%202023-11-22%20at%209.13.32%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.19.42%20AM.png](attachment:Screenshot%202023-11-22%20at%209.19.42%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.20.06%20AM.png](attachment:Screenshot%202023-11-22%20at%209.20.06%20AM.png)

# %%
def solve(cmd, stack) : 
    if cmd[0] == 'push' : 
        stack.append(cmd[1])
    elif cmd[0] == 'pop' : 
        if len(stack) == 0 : 
            print("Oops!")
        else :
            stack.pop()
    elif cmd[0] == 'peek':
        if len(stack) == 0 :
            print("None!")
        else :
            print(stack[-1])
    elif cmd[0] == 'size':
        print(len(stack))
    elif cmd[0] == "empty":
        print(len(stack) == 0)
            
n = int(input())
stack = []
for _ in range(n) : 
    cmd = input().split()
    solve(cmd, stack)
# Out:
# 16
# push A
# push B
# push C
# pop
# peek
# B
# size
# 2
# push D
# peek
# D
# size
# 3
# empty
# False
# pop
# pop
# pop
# pop
# Oops!
# peek
# None!
# empty
# True

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.31.31%20AM.png](attachment:Screenshot%202023-11-22%20at%209.31.31%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.31.49%20AM.png](attachment:Screenshot%202023-11-22%20at%209.31.49%20AM.png)
