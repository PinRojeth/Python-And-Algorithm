# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.32.31%20AM.png](attachment:Screenshot%202023-11-22%20at%209.32.31%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.38.19%20AM.png](attachment:Screenshot%202023-11-22%20at%209.38.19%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.39.14%20AM.png](attachment:Screenshot%202023-11-22%20at%209.39.14%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.45.03%20AM.png](attachment:Screenshot%202023-11-22%20at%209.45.03%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.49.40%20AM.png](attachment:Screenshot%202023-11-22%20at%209.49.40%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.52.03%20AM.png](attachment:Screenshot%202023-11-22%20at%209.52.03%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.54.39%20AM.png](attachment:Screenshot%202023-11-22%20at%209.54.39%20AM.png)

# %%
class Stack : 
    def __init__(self) : 
        self.stack = []
    def push(self, x) : 
        self.stack.append(x)
    def pop(self): 
        return None if self.empty() else self.stack.pop()
    def peek(self):
        return None if self.empty() else self.stack[-1]
    def size(self):
        return len(self.stack)
    def empty(self):
        return len(self.stack) == 0

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.15.14%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.15.14%20AM.png)

# %%
from stack import Stack

def solve(n, s) : 
    stack = Stack() 
    for i in range(n) : 
        while not stack.empty() and s[i] >= stack.peek(): 
            stack.pop()
        stack.push(s[i])
    print(stack.stack)
    return stack.size()
n = int(input())
s = list(map(int, input().split()))
print(solve(n, s))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from stack import Stack
#       3 def solve(n, s) :
#       4     stack = Stack()
#
# ModuleNotFoundError: No module named 'stack'

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.22.41%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.22.41%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.22.58%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.22.58%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.23.19%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.23.19%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.23.27%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.23.27%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.23.37%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.23.37%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.23.50%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.23.50%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.24.17%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.24.17%20AM.png)
