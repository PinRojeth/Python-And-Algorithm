# %% [markdown]
# ![Screenshot%202023-12-01%20at%209.16.16%20AM.png](attachment:Screenshot%202023-12-01%20at%209.16.16%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-01%20at%209.17.48%20AM.png](attachment:Screenshot%202023-12-01%20at%209.17.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-01%20at%209.18.17%20AM.png](attachment:Screenshot%202023-12-01%20at%209.18.17%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-01%20at%209.28.30%20AM.png](attachment:Screenshot%202023-12-01%20at%209.28.30%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-01%20at%209.31.25%20AM.png](attachment:Screenshot%202023-12-01%20at%209.31.25%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-01%20at%209.33.31%20AM.png](attachment:Screenshot%202023-12-01%20at%209.33.31%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-01%20at%209.34.02%20AM.png](attachment:Screenshot%202023-12-01%20at%209.34.02%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-01%20at%209.37.16%20AM.png](attachment:Screenshot%202023-12-01%20at%209.37.16%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-04%20at%208.50.17%20AM.png](attachment:Screenshot%202023-12-04%20at%208.50.17%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-04%20at%208.59.53%20AM.png](attachment:Screenshot%202023-12-04%20at%208.59.53%20AM.png)

# %%
def solve(X) : 
    stack = []
    for x in X : 
        if x.isdigit() : 
            stack.append(int(x))
        else : 
            b, a = stack.pop(), stack.pop()
            if x == '+' : stack.append(a + b)
            elif x == '-' : stack.append(a - b)
            elif x == '*' : stack.append(a * b)
            elif x == '/' : stack.append(a // b)
    return stack[-1]
X = input()
print(solve(X))
# Out:
# 12+7*
# 21

# %% [markdown]
# ![Screenshot%202023-12-04%20at%209.04.32%20AM.png](attachment:Screenshot%202023-12-04%20at%209.04.32%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-04%20at%209.05.02%20AM.png](attachment:Screenshot%202023-12-04%20at%209.05.02%20AM.png)
