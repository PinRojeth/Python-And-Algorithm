# %% [markdown]
# ![Screenshot%202023-12-04%20at%209.48.36%20AM.png](attachment:Screenshot%202023-12-04%20at%209.48.36%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-04%20at%209.59.08%20AM.png](attachment:Screenshot%202023-12-04%20at%209.59.08%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-04%20at%2010.56.14%20AM.png](attachment:Screenshot%202023-12-04%20at%2010.56.14%20AM.png)

# %% [markdown]
# ![Screenshot%202023-12-04%20at%2010.57.25%20AM.png](attachment:Screenshot%202023-12-04%20at%2010.57.25%20AM.png)

# %%
def solve(n, s) : 
    stack = []
    operation = ''
    j = 0 
    for i in range(1, n + 1) :
        stack.append(i)
        operation += '+'
        while stack and s[j] == stack[-1] : 
            stack.pop()
            operation += '-'
            j += 1 
    return "No" if stack else operation

n = int(input())
s = list(map(int, input().split()))
print(solve(n, s))
# Out:
# 4
# 3 4 1 2
# No

# %% [markdown]
# ![Screenshot%202023-12-04%20at%2010.59.59%20AM.png](attachment:Screenshot%202023-12-04%20at%2010.59.59%20AM.png)
