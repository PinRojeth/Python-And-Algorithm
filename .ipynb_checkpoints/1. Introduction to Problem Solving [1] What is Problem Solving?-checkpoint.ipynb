# %% [markdown]
# ![Screenshot%202023-10-02%20at%208.35.50%20AM.png](attachment:Screenshot%202023-10-02%20at%208.35.50%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20at%209.04.36%20AM.png](attachment:Screenshot%202023-10-02%20at%209.04.36%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20at%209.06.02%20AM.png](attachment:Screenshot%202023-10-02%20at%209.06.02%20AM.png)

# %%
N, M = map(int, input().split())
A = [list(map(int, input().split())) for _ in range(N)]
B = [list(map(int, input().split())) for _ in range(N)]
c = add(A, B)
print(c)
# Out:
# 2 3
# 2 3
# 2 3
# 2 3
# 2
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 A = [list(map(int, input().split())) for _ in range(N)]
#       3 B = [list(map(int, input().split())) for _ in range(M)]
# ----> 4 c = add(A, B)
#       5 print(c)
#
# NameError: name 'add' is not defined
